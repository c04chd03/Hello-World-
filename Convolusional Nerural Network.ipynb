# %% [markdown]
# <a href="https://colab.research.google.com/github/c04chd03/Hello-World-/blob/master/Convolusional%20Nerural%20Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing required libararies

# %%
import pandas as pd
import numpy as np
import scipy.special as sps
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
data = pd.read_csv('/content/data.csv')

# %% [markdown]
# # Coverting dataframe to a numpy array

# %%
data = np.array(data)

# %% [markdown]
# # Reading input and output array from data

# %%
X = data[:,:3]
Y = data[:,3]

# %% [markdown]
# # Initializing parameters

# %%
w = np.random.rand (3,)

# %%
# Maximum number of iterations.
max_iter = 500

# define an error vector to save all error values over all iterations.
error_all = []

# Learning rate for gradient descent.
eta = 0.5

# %% [markdown]
# # Training process in a for loop

# %%
for iter in range (0,max_iter):


    Y_hat = sps.expit(np.dot(X,w))

# =============================================================================
#     Compute the error below
# =============================================================================
    e = 0

    # Add this error to the end of error vector.
    e = -1/max_iter * np.sum( np.multiply(np.log(Y_hat), Y) + np.multiply(np.log(1-Y_hat), (1-Y)))

    #append error value in the error_all vector
    error_all.append(e)

    # Gradient of the error
    grad_e = np.mean(np.multiply((Y_hat - Y), X.T), axis=1)

    w_old = w
    w = w - eta*grad_e


    print ('epoch {0:d}, negative log-likelihood {1:.4f}, w={2}'.format(iter, e, w.T))
# Out:
# epoch 0, negative log-likelihood 1.0224, w=[-0.37163092  0.05218595  0.39669652]
# epoch 1, negative log-likelihood 0.4989, w=[ 0.90914159 -0.07791863  0.56660183]
# epoch 2, negative log-likelihood 1.0107, w=[-0.32211181 -0.26915155  0.32070088]
# epoch 3, negative log-likelihood 0.4312, w=[ 0.88423151 -0.35753675  0.47608017]
# epoch 4, negative log-likelihood 0.9259, w=[-0.34325762 -0.54614128  0.23072507]
# epoch 5, negative log-likelihood 0.4472, w=[ 0.90747207 -0.60556555  0.39262613]
# epoch 6, negative log-likelihood 0.8951, w=[-0.31727307 -0.79157364  0.1476475 ]
# epoch 7, negative log-likelihood 0.4234, w=[ 0.8685079  -0.82308916  0.29763029]
# epoch 8, negative log-likelihood 0.8067, w=[-0.34276227 -1.00380805  0.05532167]
# epoch 9, negative log-likelihood 0.4549, w=[ 0.87703389 -1.02378674  0.21073686]
# epoch 10, negative log-likelihood 0.7696, w=[-0.32181615 -1.19858195 -0.0291833 ]
# epoch 11, negative log-likelihood 0.4434, w=[ 0.84465858 -1.20096921  0.11690267]
# epoch 12, negative log-likelihood 0.6970, w=[-0.32478361 -1.36390329 -0.11735701]
# epoch 13, negative log-likelihood 0.4566, w=[ 0.83698402 -1.35786094  0.02786285]
# epoch 14, negative log-likelihood 0.6538, w=[-0.30208119 -1.50816484 -0.20071767]
# epoch 15, negative log-likelihood 0.4468, w=[ 0.81366473 -1.49052362 -0.06323496]
# epoch 16, negative log-likelihood 0.6015, w=[-0.28087887 -1.62358116 -0.28369362]
# epoch 17, negative log-likelihood 0.4391, w=[ 0.79777743 -1.59733118 -0.1523142 ]
# epoch 18, negative log-likelihood 0.5617, w=[-0.25229928 -1.71374603 -0.36483574]
# epoch 19, negative log-likelihood 0.4254, w=[ 0.78124606 -1.6793746  -0.24079658]
# epoch 20, negative log-likelihood 0.5262, w=[-0.22357527 -1.77974844 -0.44533921]
# epoch 21, negative log-likelihood 0.4119, w=[ 0.76915263 -1.73897716 -0.3278407 ]
# epoch 22, negative log-likelihood 0.4982, w=[-0.19635481 -1.82610515 -0.52547892]
# epoch 23, negative log-likelihood 0.3996, w=[ 0.76177904 -1.78051821 -0.41343075]
# epoch 24, negative log-likelihood 0.4766, w=[-0.17189322 -1.85744161 -0.605461  ]
# epoch 25, negative log-likelihood 0.3894, w=[ 0.7592983  -1.80845836 -0.49756175]
# epoch 26, negative log-likelihood 0.4603, w=[-0.15025295 -1.87799262 -0.68530303]
# epoch 27, negative log-likelihood 0.3811, w=[ 0.76102678 -1.82672009 -0.5803717 ]
# epoch 28, negative log-likelihood 0.4482, w=[-0.13100739 -1.89110629 -0.76494727]
# epoch 29, negative log-likelihood 0.3743, w=[ 0.76602303 -1.8383483  -0.66203924]
# epoch 30, negative log-likelihood 0.4392, w=[-0.11360477 -1.89923366 -0.84431643]
# epoch 31, negative log-likelihood 0.3687, w=[ 0.77338109 -1.84554864 -0.74273329]
# epoch 32, negative log-likelihood 0.4323, w=[-0.09754148 -1.9040849  -0.92333948]
# epoch 33, negative log-likelihood 0.3640, w=[ 0.78235544 -1.84984987 -0.8225917 ]
# epoch 34, negative log-likelihood 0.4268, w=[-0.08241876 -1.90681531 -1.00195992]
# epoch 35, negative log-likelihood 0.3598, w=[ 0.79238384 -1.85227993 -0.90171784]
# epoch 36, negative log-likelihood 0.4223, w=[-0.06794503 -1.90818711 -1.08013619]
# epoch 37, negative log-likelihood 0.3560, w=[ 0.80306565 -1.85351458 -0.98018492]
# epoch 38, negative log-likelihood 0.4184, w=[-0.05391787 -1.90869414 -1.15783912]
# epoch 39, negative log-likelihood 0.3525, w=[ 0.81412645 -1.85399036 -1.05804266]
# epoch 40, negative log-likelihood 0.4149, w=[-0.04020178 -1.9086518  -1.23504878]
# epoch 41, negative log-likelihood 0.3491, w=[ 0.82538373 -1.85398546 -1.13532373]
# epoch 42, negative log-likelihood 0.4117, w=[-0.0267084  -1.90825933 -1.31175176]
# epoch 43, negative log-likelihood 0.3459, w=[ 0.83671865 -1.85367526 -1.21204894]
# epoch 44, negative log-likelihood 0.4086, w=[-0.01338124 -1.90764149 -1.38793903]
# epoch 45, negative log-likelihood 0.3428, w=[ 0.84805506 -1.85316943 -1.28823118]
# epoch 46, negative log-likelihood 0.4056, w=[-1.84735971e-04 -1.90687596e+00 -1.46360442e+00]
# epoch 47, negative log-likelihood 0.3397, w=[ 0.85934464 -1.85253613 -1.36387817]
# epoch 48, negative log-likelihood 0.4027, w=[ 0.01290327 -1.90601085 -1.53874363]
# epoch 49, negative log-likelihood 0.3366, w=[ 0.87055701 -1.85181756 -1.43899429]
# epoch 50, negative log-likelihood 0.3998, w=[ 0.0258964  -1.90507589 -1.61335352]
# epoch 51, negative log-likelihood 0.3337, w=[ 0.88167311 -1.85103974 -1.51358183]
# epoch 52, negative log-likelihood 0.3970, w=[ 0.03880296 -1.90408942 -1.68743168]
# epoch 53, negative log-likelihood 0.3307, w=[ 0.89268102 -1.85021869 -1.58764177]
# epoch 54, negative log-likelihood 0.3942, w=[ 0.05162794 -1.90306275 -1.7609762 ]
# epoch 55, negative log-likelihood 0.3278, w=[ 0.90357325 -1.84936429 -1.6611743 ]
# epoch 56, negative log-likelihood 0.3913, w=[ 0.0643743  -1.90200291 -1.83398547]
# epoch 57, negative log-likelihood 0.3249, w=[ 0.91434511 -1.84848263 -1.73417911]
# epoch 58, negative log-likelihood 0.3885, w=[ 0.07704371 -1.90091427 -1.90645807]
# epoch 59, negative log-likelihood 0.3220, w=[ 0.92499361 -1.84757751 -1.8066556 ]
# epoch 60, negative log-likelihood 0.3857, w=[ 0.08963709 -1.89979959 -1.97839274]
# epoch 61, negative log-likelihood 0.3192, w=[ 0.93551682 -1.84665129 -1.87860302]
# epoch 62, negative log-likelihood 0.3829, w=[ 0.10215491 -1.89866069 -2.04978832]
# epoch 63, negative log-likelihood 0.3164, w=[ 0.94591349 -1.84570552 -1.95002053]
# epoch 64, negative log-likelihood 0.3801, w=[ 0.11459735 -1.89749875 -2.12064371]
# epoch 65, negative log-likelihood 0.3136, w=[ 0.95618278 -1.84474119 -2.02090725]
# epoch 66, negative log-likelihood 0.3773, w=[ 0.1269644  -1.89631462 -2.1909579 ]
# epoch 67, negative log-likelihood 0.3108, w=[ 0.9663241  -1.84375901 -2.09126229]
# epoch 68, negative log-likelihood 0.3745, w=[ 0.139256   -1.89510894 -2.26072993]
# epoch 69, negative log-likelihood 0.3081, w=[ 0.97633704 -1.84275947 -2.16108479]
# epoch 70, negative log-likelihood 0.3717, w=[ 0.15147199 -1.8938822  -2.32995888]
# epoch 71, negative log-likelihood 0.3054, w=[ 0.98622132 -1.841743   -2.2303739 ]
# epoch 72, negative log-likelihood 0.3689, w=[ 0.16361221 -1.89263484 -2.3986439 ]
# epoch 73, negative log-likelihood 0.3027, w=[ 0.9959767  -1.84070991 -2.2991288 ]
# epoch 74, negative log-likelihood 0.3661, w=[ 0.17567648 -1.89136723 -2.46678418]
# epoch 75, negative log-likelihood 0.3001, w=[ 1.00560305 -1.83966052 -2.36734872]
# epoch 76, negative log-likelihood 0.3633, w=[ 0.18766461 -1.89007976 -2.53437897]
# epoch 77, negative log-likelihood 0.2974, w=[ 1.01510024 -1.8385951  -2.43503292]
# epoch 78, negative log-likelihood 0.3606, w=[ 0.19957642 -1.88877275 -2.60142757]
# epoch 79, negative log-likelihood 0.2948, w=[ 1.02446821 -1.83751393 -2.5021807 ]
# epoch 80, negative log-likelihood 0.3578, w=[ 0.21141172 -1.88744657 -2.66792932]
# epoch 81, negative log-likelihood 0.2923, w=[ 1.03370693 -1.83641726 -2.56879143]
# epoch 82, negative log-likelihood 0.3550, w=[ 0.22317034 -1.88610154 -2.73388363]
# epoch 83, negative log-likelihood 0.2897, w=[ 1.04281642 -1.83530537 -2.63486451]
# epoch 84, negative log-likelihood 0.3523, w=[ 0.2348521  -1.884738   -2.79928997]
# epoch 85, negative log-likelihood 0.2872, w=[ 1.05179671 -1.83417851 -2.70039939]
# epoch 86, negative log-likelihood 0.3495, w=[ 0.24645685 -1.88335631 -2.86414787]
# epoch 87, negative log-likelihood 0.2847, w=[ 1.06064789 -1.83303696 -2.76539558]
# epoch 88, negative log-likelihood 0.3467, w=[ 0.25798444 -1.8819568  -2.92845691]
# epoch 89, negative log-likelihood 0.2822, w=[ 1.06937007 -1.83188098 -2.82985265]
# epoch 90, negative log-likelihood 0.3440, w=[ 0.26943471 -1.88053982 -2.99221674]
# epoch 91, negative log-likelihood 0.2798, w=[ 1.07796341 -1.83071085 -2.89377022]
# epoch 92, negative log-likelihood 0.3412, w=[ 0.28080754 -1.8791057  -3.05542709]
# epoch 93, negative log-likelihood 0.2773, w=[ 1.08642811 -1.82952683 -2.95714799]
# epoch 94, negative log-likelihood 0.3385, w=[ 0.29210278 -1.87765482 -3.11808774]
# epoch 95, negative log-likelihood 0.2749, w=[ 1.09476441 -1.82832921 -3.01998571]
# epoch 96, negative log-likelihood 0.3357, w=[ 0.30332032 -1.8761875  -3.18019857]
# epoch 97, negative log-likelihood 0.2726, w=[ 1.10297257 -1.82711827 -3.08228319]
# epoch 98, negative log-likelihood 0.3330, w=[ 0.31446003 -1.87470412 -3.24175952]
# epoch 99, negative log-likelihood 0.2702, w=[ 1.11105292 -1.8258943  -3.14404033]
# epoch 100, negative log-likelihood 0.3303, w=[ 0.32552183 -1.87320503 -3.30277061]
# epoch 101, negative log-likelihood 0.2679, w=[ 1.11900583 -1.82465756 -3.20525709]
# epoch 102, negative log-likelihood 0.3276, w=[ 0.3365056  -1.87169058 -3.36323194]
# epoch 103, negative log-likelihood 0.2656, w=[ 1.1268317  -1.82340837 -3.26593352]
# epoch 104, negative log-likelihood 0.3249, w=[ 0.34741127 -1.87016115 -3.42314371]
# epoch 105, negative log-likelihood 0.2633, w=[ 1.13453098 -1.82214702 -3.32606974]
# epoch 106, negative log-likelihood 0.3221, w=[ 0.35823874 -1.86861711 -3.48250621]
# epoch 107, negative log-likelihood 0.2610, w=[ 1.14210417 -1.82087381 -3.38566595]
# epoch 108, negative log-likelihood 0.3195, w=[ 0.36898796 -1.86705882 -3.5413198 ]
# epoch 109, negative log-likelihood 0.2588, w=[ 1.14955182 -1.81958903 -3.44472244]
# epoch 110, negative log-likelihood 0.3168, w=[ 0.37965886 -1.86548667 -3.59958496]
# epoch 111, negative log-likelihood 0.2566, w=[ 1.15687452 -1.81829302 -3.5032396 ]
# epoch 112, negative log-likelihood 0.3141, w=[ 0.39025139 -1.86390104 -3.65730226]
# epoch 113, negative log-likelihood 0.2544, w=[ 1.1640729  -1.81698607 -3.5612179 ]
# epoch 114, negative log-likelihood 0.3114, w=[ 0.40076552 -1.86230233 -3.71447236]
# epoch 115, negative log-likelihood 0.2522, w=[ 1.17114764 -1.81566853 -3.61865791]
# epoch 116, negative log-likelihood 0.3087, w=[ 0.41120122 -1.86069093 -3.77109603]
# epoch 117, negative log-likelihood 0.2501, w=[ 1.17809947 -1.81434072 -3.67556028]
# epoch 118, negative log-likelihood 0.3061, w=[ 0.42155849 -1.85906725 -3.82717416]
# epoch 119, negative log-likelihood 0.2480, w=[ 1.18492918 -1.81300299 -3.73192579]
# epoch 120, negative log-likelihood 0.3034, w=[ 0.43183731 -1.85743171 -3.88270772]
# epoch 121, negative log-likelihood 0.2459, w=[ 1.19163757 -1.81165567 -3.7877553 ]
# epoch 122, negative log-likelihood 0.3008, w=[ 0.4420377  -1.85578472 -3.93769782]
# epoch 123, negative log-likelihood 0.2438, w=[ 1.1982255  -1.81029913 -3.84304979]
# epoch 124, negative log-likelihood 0.2982, w=[ 0.4521597  -1.85412672 -3.99214565]
# epoch 125, negative log-likelihood 0.2417, w=[ 1.2046939  -1.80893374 -3.89781032]
# epoch 126, negative log-likelihood 0.2956, w=[ 0.46220334 -1.85245815 -4.04605254]
# epoch 127, negative log-likelihood 0.2397, w=[ 1.21104371 -1.80755988 -3.95203808]
# epoch 128, negative log-likelihood 0.2930, w=[ 0.47216868 -1.85077946 -4.0994199 ]
# epoch 129, negative log-likelihood 0.2377, w=[ 1.21727592 -1.80617792 -4.00573436]
# epoch 130, negative log-likelihood 0.2904, w=[ 0.48205581 -1.84909111 -4.15224929]
# epoch 131, negative log-likelihood 0.2357, w=[ 1.22339155 -1.80478826 -4.05890057]
# epoch 132, negative log-likelihood 0.2878, w=[ 0.4918648  -1.84739358 -4.20454236]
# epoch 133, negative log-likelihood 0.2338, w=[ 1.22939169 -1.80339132 -4.11153822]
# epoch 134, negative log-likelihood 0.2852, w=[ 0.50159577 -1.84568735 -4.25630088]
# epoch 135, negative log-likelihood 0.2318, w=[ 1.23527744 -1.8019875  -4.16364893]
# epoch 136, negative log-likelihood 0.2827, w=[ 0.51124885 -1.8439729  -4.30752675]
# epoch 137, negative log-likelihood 0.2299, w=[ 1.24104994 -1.80057723 -4.21523444]
# epoch 138, negative log-likelihood 0.2801, w=[ 0.52082417 -1.84225074 -4.35822195]
# epoch 139, negative log-likelihood 0.2280, w=[ 1.24671037 -1.79916095 -4.2662966 ]
# epoch 140, negative log-likelihood 0.2776, w=[ 0.53032191 -1.84052138 -4.40838861]
# epoch 141, negative log-likelihood 0.2261, w=[ 1.25225993 -1.7977391  -4.31683736]
# epoch 142, negative log-likelihood 0.2751, w=[ 0.53974223 -1.83878536 -4.45802895]
# epoch 143, negative log-likelihood 0.2243, w=[ 1.25769987 -1.79631214 -4.3668588 ]
# epoch 144, negative log-likelihood 0.2726, w=[ 0.54908535 -1.83704318 -4.5071453 ]
# epoch 145, negative log-likelihood 0.2224, w=[ 1.26303144 -1.79488052 -4.41636309]
# epoch 146, negative log-likelihood 0.2701, w=[ 0.55835148 -1.83529541 -4.55574012]
# epoch 147, negative log-likelihood 0.2206, w=[ 1.26825593 -1.79344473 -4.46535252]
# epoch 148, negative log-likelihood 0.2677, w=[ 0.56754086 -1.83354258 -4.60381596]
# epoch 149, negative log-likelihood 0.2188, w=[ 1.27337466 -1.79200523 -4.51382948]
# epoch 150, negative log-likelihood 0.2652, w=[ 0.57665374 -1.83178525 -4.65137548]
# epoch 151, negative log-likelihood 0.2170, w=[ 1.27838895 -1.79056251 -4.56179648]
# epoch 152, negative log-likelihood 0.2628, w=[ 0.5856904  -1.83002399 -4.69842145]
# epoch 153, negative log-likelihood 0.2153, w=[ 1.28330017 -1.78911707 -4.60925612]
# epoch 154, negative log-likelihood 0.2604, w=[ 0.59465115 -1.82825936 -4.74495672]
# epoch 155, negative log-likelihood 0.2136, w=[ 1.28810967 -1.78766939 -4.65621111]
# epoch 156, negative log-likelihood 0.2580, w=[ 0.60353628 -1.82649194 -4.79098428]
# epoch 157, negative log-likelihood 0.2118, w=[ 1.29281883 -1.78621999 -4.70266424]
# epoch 158, negative log-likelihood 0.2556, w=[ 0.61234615 -1.8247223  -4.83650716]
# epoch 159, negative log-likelihood 0.2101, w=[ 1.29742904 -1.78476935 -4.74861843]
# epoch 160, negative log-likelihood 0.2533, w=[ 0.6210811  -1.82295103 -4.88152854]
# epoch 161, negative log-likelihood 0.2085, w=[ 1.30194171 -1.783318   -4.79407667]
# epoch 162, negative log-likelihood 0.2509, w=[ 0.62974149 -1.8211787  -4.92605164]
# epoch 163, negative log-likelihood 0.2068, w=[ 1.30635824 -1.78186642 -4.83904204]
# epoch 164, negative log-likelihood 0.2486, w=[ 0.63832774 -1.81940589 -4.9700798 ]
# epoch 165, negative log-likelihood 0.2052, w=[ 1.31068003 -1.78041514 -4.88351772]
# epoch 166, negative log-likelihood 0.2463, w=[ 0.64684023 -1.8176332  -5.01361642]
# epoch 167, negative log-likelihood 0.2036, w=[ 1.3149085  -1.77896465 -4.92750697]
# epoch 168, negative log-likelihood 0.2440, w=[ 0.6552794  -1.81586118 -5.05666501]
# epoch 169, negative log-likelihood 0.2020, w=[ 1.31904506 -1.77751546 -4.97101313]
# epoch 170, negative log-likelihood 0.2418, w=[ 0.66364569 -1.81409043 -5.09922911]
# epoch 171, negative log-likelihood 0.2004, w=[ 1.32309112 -1.77606807 -5.01403961]
# epoch 172, negative log-likelihood 0.2395, w=[ 0.67193956 -1.81232151 -5.14131236]
# epoch 173, negative log-likelihood 0.1989, w=[ 1.32704808 -1.77462297 -5.05658992]
# epoch 174, negative log-likelihood 0.2373, w=[ 0.68016148 -1.81055498 -5.18291847]
# epoch 175, negative log-likelihood 0.1973, w=[ 1.33091735 -1.77318065 -5.0986676 ]
# epoch 176, negative log-likelihood 0.2351, w=[ 0.68831195 -1.8087914  -5.22405121]
# epoch 177, negative log-likelihood 0.1958, w=[ 1.33470031 -1.7717416  -5.1402763 ]
# epoch 178, negative log-likelihood 0.2329, w=[ 0.69639147 -1.80703132 -5.26471439]
# epoch 179, negative log-likelihood 0.1943, w=[ 1.33839835 -1.77030628 -5.1814197 ]
# epoch 180, negative log-likelihood 0.2308, w=[ 0.70440056 -1.80527527 -5.3049119 ]
# epoch 181, negative log-likelihood 0.1928, w=[ 1.34201283 -1.76887517 -5.22210154]
# epoch 182, negative log-likelihood 0.2286, w=[ 0.71233977 -1.80352379 -5.34464767]
# epoch 183, negative log-likelihood 0.1914, w=[ 1.34554513 -1.76744871 -5.26232565]
# epoch 184, negative log-likelihood 0.2265, w=[ 0.72020962 -1.80177738 -5.38392568]
# epoch 185, negative log-likelihood 0.1899, w=[ 1.34899657 -1.76602735 -5.30209587]
# epoch 186, negative log-likelihood 0.2244, w=[ 0.72801069 -1.80003656 -5.42274995]
# epoch 187, negative log-likelihood 0.1885, w=[ 1.3523685  -1.76461152 -5.34141611]
# epoch 188, negative log-likelihood 0.2224, w=[ 0.73574355 -1.7983018  -5.46112455]
# epoch 189, negative log-likelihood 0.1871, w=[ 1.35566222 -1.76320165 -5.38029032]
# epoch 190, negative log-likelihood 0.2203, w=[ 0.74340879 -1.79657359 -5.49905358]
# epoch 191, negative log-likelihood 0.1857, w=[ 1.35887903 -1.76179814 -5.41872247]
# epoch 192, negative log-likelihood 0.2183, w=[ 0.75100699 -1.79485237 -5.53654116]
# epoch 193, negative log-likelihood 0.1843, w=[ 1.36202022 -1.76040137 -5.45671661]
# epoch 194, negative log-likelihood 0.2163, w=[ 0.75853876 -1.79313859 -5.57359145]
# epoch 195, negative log-likelihood 0.1830, w=[ 1.36508704 -1.75901173 -5.49427677]
# epoch 196, negative log-likelihood 0.2143, w=[ 0.76600472 -1.79143268 -5.61020865]
# epoch 197, negative log-likelihood 0.1816, w=[ 1.36808073 -1.75762958 -5.53140705]
# epoch 198, negative log-likelihood 0.2123, w=[ 0.77340549 -1.78973505 -5.64639695]
# epoch 199, negative log-likelihood 0.1803, w=[ 1.37100252 -1.75625527 -5.56811155]
# epoch 200, negative log-likelihood 0.2104, w=[ 0.7807417  -1.78804607 -5.68216057]
# epoch 201, negative log-likelihood 0.1790, w=[ 1.37385361 -1.75488912 -5.60439441]
# epoch 202, negative log-likelihood 0.2084, w=[ 0.78801398 -1.78636612 -5.71750376]
# epoch 203, negative log-likelihood 0.1777, w=[ 1.37663517 -1.75353144 -5.64025977]
# epoch 204, negative log-likelihood 0.2065, w=[ 0.795223   -1.78469555 -5.75243077]
# epoch 205, negative log-likelihood 0.1764, w=[ 1.37934838 -1.75218254 -5.67571179]
# epoch 206, negative log-likelihood 0.2047, w=[ 0.80236939 -1.7830347  -5.78694584]
# epoch 207, negative log-likelihood 0.1752, w=[ 1.38199436 -1.7508427  -5.71075465]
# epoch 208, negative log-likelihood 0.2028, w=[ 0.80945381 -1.78138388 -5.82105325]
# epoch 209, negative log-likelihood 0.1739, w=[ 1.38457423 -1.74951217 -5.74539253]
# epoch 210, negative log-likelihood 0.2010, w=[ 0.81647693 -1.77974338 -5.85475725]
# epoch 211, negative log-likelihood 0.1727, w=[ 1.3870891  -1.74819121 -5.77962963]
# epoch 212, negative log-likelihood 0.1992, w=[ 0.82343942 -1.77811349 -5.88806211]
# epoch 213, negative log-likelihood 0.1715, w=[ 1.38954002 -1.74688005 -5.81347013]
# epoch 214, negative log-likelihood 0.1974, w=[ 0.83034195 -1.77649446 -5.92097209]
# epoch 215, negative log-likelihood 0.1703, w=[ 1.39192807 -1.7455789  -5.84691824]
# epoch 216, negative log-likelihood 0.1956, w=[ 0.83718519 -1.77488653 -5.95349145]
# epoch 217, negative log-likelihood 0.1691, w=[ 1.39425427 -1.74428795 -5.87997812]
# epoch 218, negative log-likelihood 0.1939, w=[ 0.84396983 -1.77328992 -5.98562442]
# epoch 219, negative log-likelihood 0.1679, w=[ 1.39651963 -1.7430074  -5.91265399]
# epoch 220, negative log-likelihood 0.1921, w=[ 0.85069655 -1.77170483 -6.01737526]
# epoch 221, negative log-likelihood 0.1668, w=[ 1.39872514 -1.74173741 -5.94495   ]
# epoch 222, negative log-likelihood 0.1904, w=[ 0.85736602 -1.77013147 -6.04874817]
# epoch 223, negative log-likelihood 0.1657, w=[ 1.40087177 -1.74047813 -5.97687034]
# epoch 224, negative log-likelihood 0.1887, w=[ 0.86397895 -1.76856999 -6.07974738]
# epoch 225, negative log-likelihood 0.1645, w=[ 1.40296047 -1.73922969 -6.00841916]
# epoch 226, negative log-likelihood 0.1871, w=[ 0.87053601 -1.76702054 -6.11037708]
# epoch 227, negative log-likelihood 0.1634, w=[ 1.40499217 -1.73799223 -6.0396006 ]
# epoch 228, negative log-likelihood 0.1854, w=[ 0.8770379  -1.76548328 -6.14064143]
# epoch 229, negative log-likelihood 0.1623, w=[ 1.40696778 -1.73676585 -6.07041879]
# epoch 230, negative log-likelihood 0.1838, w=[ 0.8834853  -1.76395832 -6.1705446 ]
# epoch 231, negative log-likelihood 0.1612, w=[ 1.40888818 -1.73555065 -6.10087786]
# epoch 232, negative log-likelihood 0.1822, w=[ 0.88987892 -1.76244578 -6.20009072]
# epoch 233, negative log-likelihood 0.1602, w=[ 1.41075425 -1.73434672 -6.13098188]
# epoch 234, negative log-likelihood 0.1806, w=[ 0.89621943 -1.76094574 -6.22928391]
# epoch 235, negative log-likelihood 0.1591, w=[ 1.41256684 -1.73315412 -6.16073494]
# epoch 236, negative log-likelihood 0.1791, w=[ 0.90250755 -1.75945829 -6.25812824]
# epoch 237, negative log-likelihood 0.1581, w=[ 1.41432677 -1.73197293 -6.19014108]
# epoch 238, negative log-likelihood 0.1775, w=[ 0.90874394 -1.75798351 -6.28662779]
# epoch 239, negative log-likelihood 0.1570, w=[ 1.41603487 -1.73080318 -6.21920434]
# epoch 240, negative log-likelihood 0.1760, w=[ 0.91492932 -1.75652144 -6.31478659]
# epoch 241, negative log-likelihood 0.1560, w=[ 1.41769193 -1.72964494 -6.24792873]
# epoch 242, negative log-likelihood 0.1745, w=[ 0.92106436 -1.75507215 -6.34260864]
# epoch 243, negative log-likelihood 0.1550, w=[ 1.41929873 -1.72849822 -6.27631822]
# epoch 244, negative log-likelihood 0.1730, w=[ 0.92714976 -1.75363567 -6.37009793]
# epoch 245, negative log-likelihood 0.1540, w=[ 1.42085602 -1.72736306 -6.30437677]
# epoch 246, negative log-likelihood 0.1716, w=[ 0.93318622 -1.75221202 -6.39725841]
# epoch 247, negative log-likelihood 0.1530, w=[ 1.42236456 -1.72623947 -6.33210831]
# epoch 248, negative log-likelihood 0.1701, w=[ 0.93917441 -1.75080123 -6.424094  ]
# epoch 249, negative log-likelihood 0.1521, w=[ 1.42382506 -1.72512746 -6.35951673]
# epoch 250, negative log-likelihood 0.1687, w=[ 0.94511504 -1.74940331 -6.45060859]
# epoch 251, negative log-likelihood 0.1511, w=[ 1.42523825 -1.72402704 -6.38660592]
# epoch 252, negative log-likelihood 0.1673, w=[ 0.95100878 -1.74801826 -6.47680603]
# epoch 253, negative log-likelihood 0.1502, w=[ 1.4266048  -1.7229382  -6.41337971]
# epoch 254, negative log-likelihood 0.1659, w=[ 0.95685631 -1.74664609 -6.50269016]
# epoch 255, negative log-likelihood 0.1492, w=[ 1.42792541 -1.72186094 -6.43984192]
# epoch 256, negative log-likelihood 0.1645, w=[ 0.96265834 -1.74528678 -6.52826476]
# epoch 257, negative log-likelihood 0.1483, w=[ 1.42920074 -1.72079525 -6.46599633]
# epoch 258, negative log-likelihood 0.1632, w=[ 0.96841553 -1.74394033 -6.55353361]
# epoch 259, negative log-likelihood 0.1474, w=[ 1.43043143 -1.71974112 -6.4918467 ]
# epoch 260, negative log-likelihood 0.1619, w=[ 0.97412858 -1.74260671 -6.57850042]
# epoch 261, negative log-likelihood 0.1465, w=[ 1.43161811 -1.71869852 -6.51739673]
# epoch 262, negative log-likelihood 0.1606, w=[ 0.97979815 -1.7412859  -6.6031689 ]
# epoch 263, negative log-likelihood 0.1456, w=[ 1.43276141 -1.71766743 -6.54265013]
# epoch 264, negative log-likelihood 0.1593, w=[ 0.98542494 -1.73997788 -6.6275427 ]
# epoch 265, negative log-likelihood 0.1447, w=[ 1.43386192 -1.71664784 -6.56761055]
# epoch 266, negative log-likelihood 0.1580, w=[ 0.99100961 -1.73868262 -6.65162545]
# epoch 267, negative log-likelihood 0.1439, w=[ 1.43492024 -1.71563972 -6.59228162]
# epoch 268, negative log-likelihood 0.1567, w=[ 0.99655285 -1.73740009 -6.67542074]
# epoch 269, negative log-likelihood 0.1430, w=[ 1.43593694 -1.71464304 -6.61666693]
# epoch 270, negative log-likelihood 0.1555, w=[ 1.00205532 -1.73613027 -6.69893213]
# epoch 271, negative log-likelihood 0.1422, w=[ 1.43691258 -1.71365778 -6.64077005]
# epoch 272, negative log-likelihood 0.1543, w=[ 1.00751771 -1.73487311 -6.72216315]
# epoch 273, negative log-likelihood 0.1413, w=[ 1.4378477  -1.71268391 -6.6645945 ]
# epoch 274, negative log-likelihood 0.1530, w=[ 1.01294068 -1.73362859 -6.74511728]
# epoch 275, negative log-likelihood 0.1405, w=[ 1.43874286 -1.71172142 -6.68814378]
# epoch 276, negative log-likelihood 0.1519, w=[ 1.01832491 -1.73239667 -6.76779798]
# epoch 277, negative log-likelihood 0.1397, w=[ 1.43959855 -1.71077028 -6.71142135]
# epoch 278, negative log-likelihood 0.1507, w=[ 1.02367107 -1.73117732 -6.79020867]
# epoch 279, negative log-likelihood 0.1389, w=[ 1.4404153  -1.70983046 -6.73443065]
# epoch 280, negative log-likelihood 0.1495, w=[ 1.02897982 -1.72997052 -6.81235274]
# epoch 281, negative log-likelihood 0.1381, w=[ 1.44119359 -1.70890195 -6.75717508]
# epoch 282, negative log-likelihood 0.1484, w=[ 1.03425183 -1.72877622 -6.83423354]
# epoch 283, negative log-likelihood 0.1373, w=[ 1.44193391 -1.70798473 -6.779658  ]
# epoch 284, negative log-likelihood 0.1473, w=[ 1.03948777 -1.7275944  -6.85585439]
# epoch 285, negative log-likelihood 0.1365, w=[ 1.44263674 -1.70707879 -6.80188276]
# epoch 286, negative log-likelihood 0.1462, w=[ 1.0446883  -1.72642505 -6.87721857]
# epoch 287, negative log-likelihood 0.1357, w=[ 1.44330251 -1.70618412 -6.82385265]
# epoch 288, negative log-likelihood 0.1451, w=[ 1.0498541  -1.72526812 -6.89832934]
# epoch 289, negative log-likelihood 0.1350, w=[ 1.44393169 -1.70530071 -6.84557096]
# epoch 290, negative log-likelihood 0.1440, w=[ 1.05498582 -1.72412362 -6.91918991]
# epoch 291, negative log-likelihood 0.1342, w=[ 1.44452471 -1.70442856 -6.86704091]
# epoch 292, negative log-likelihood 0.1429, w=[ 1.06008413 -1.72299151 -6.93980347]
# epoch 293, negative log-likelihood 0.1335, w=[ 1.44508198 -1.70356767 -6.88826573]
# epoch 294, negative log-likelihood 0.1419, w=[ 1.06514969 -1.7218718  -6.96017317]
# epoch 295, negative log-likelihood 0.1327, w=[ 1.44560393 -1.70271805 -6.90924859]
# epoch 296, negative log-likelihood 0.1409, w=[ 1.07018317 -1.72076447 -6.98030214]
# epoch 297, negative log-likelihood 0.1320, w=[ 1.44609094 -1.70187972 -6.92999264]
# epoch 298, negative log-likelihood 0.1398, w=[ 1.07518522 -1.71966952 -7.00019345]
# epoch 299, negative log-likelihood 0.1313, w=[ 1.44654342 -1.70105269 -6.95050101]
# epoch 300, negative log-likelihood 0.1388, w=[ 1.08015652 -1.71858695 -7.01985018]
# epoch 301, negative log-likelihood 0.1306, w=[ 1.44696173 -1.70023699 -6.97077677]
# epoch 302, negative log-likelihood 0.1379, w=[ 1.08509772 -1.71751678 -7.03927533]
# epoch 303, negative log-likelihood 0.1299, w=[ 1.44734625 -1.69943265 -6.99082299]
# epoch 304, negative log-likelihood 0.1369, w=[ 1.09000949 -1.71645903 -7.05847192]
# epoch 305, negative log-likelihood 0.1292, w=[ 1.44769733 -1.69863971 -7.01064271]
# epoch 306, negative log-likelihood 0.1359, w=[ 1.09489248 -1.71541371 -7.07744289]
# epoch 307, negative log-likelihood 0.1285, w=[ 1.44801532 -1.69785822 -7.03023892]
# epoch 308, negative log-likelihood 0.1350, w=[ 1.09974737 -1.71438085 -7.0961912 ]
# epoch 309, negative log-likelihood 0.1279, w=[ 1.44830057 -1.69708823 -7.0496146 ]
# epoch 310, negative log-likelihood 0.1341, w=[ 1.10457481 -1.7133605  -7.11471973]
# epoch 311, negative log-likelihood 0.1272, w=[ 1.4485534  -1.69632982 -7.06877269]
# epoch 312, negative log-likelihood 0.1331, w=[ 1.10937546 -1.7123527  -7.13303137]
# epoch 313, negative log-likelihood 0.1265, w=[ 1.44877414 -1.69558304 -7.08771613]
# epoch 314, negative log-likelihood 0.1322, w=[ 1.11415    -1.7113575  -7.15112897]
# epoch 315, negative log-likelihood 0.1259, w=[ 1.4489631  -1.69484799 -7.10644779]
# epoch 316, negative log-likelihood 0.1314, w=[ 1.11889908 -1.71037497 -7.16901535]
# epoch 317, negative log-likelihood 0.1252, w=[ 1.44912058 -1.69412475 -7.12497054]
# epoch 318, negative log-likelihood 0.1305, w=[ 1.12362336 -1.70940519 -7.18669329]
# epoch 319, negative log-likelihood 0.1246, w=[ 1.44924689 -1.69341343 -7.14328724]
# epoch 320, negative log-likelihood 0.1296, w=[ 1.12832352 -1.70844824 -7.20416558]
# epoch 321, negative log-likelihood 0.1240, w=[ 1.44934232 -1.69271414 -7.16140069]
# epoch 322, negative log-likelihood 0.1288, w=[ 1.1330002  -1.7075042  -7.22143494]
# epoch 323, negative log-likelihood 0.1234, w=[ 1.44940717 -1.69202702 -7.17931368]
# epoch 324, negative log-likelihood 0.1280, w=[ 1.13765408 -1.70657321 -7.2385041 ]
# epoch 325, negative log-likelihood 0.1228, w=[ 1.4494417  -1.69135219 -7.19702899]
# epoch 326, negative log-likelihood 0.1271, w=[ 1.14228581 -1.70565536 -7.25537575]
# epoch 327, negative log-likelihood 0.1221, w=[ 1.44944621 -1.69068981 -7.21454936]
# epoch 328, negative log-likelihood 0.1263, w=[ 1.14689606 -1.70475079 -7.27205256]
# epoch 329, negative log-likelihood 0.1216, w=[ 1.44942098 -1.69004004 -7.23187751]
# epoch 330, negative log-likelihood 0.1256, w=[ 1.15148548 -1.70385966 -7.28853717]
# epoch 331, negative log-likelihood 0.1210, w=[ 1.44936626 -1.68940307 -7.24901614]
# epoch 332, negative log-likelihood 0.1248, w=[ 1.15605473 -1.70298212 -7.30483221]
# epoch 333, negative log-likelihood 0.1204, w=[ 1.44928236 -1.68877908 -7.26596792]
# epoch 334, negative log-likelihood 0.1240, w=[ 1.16060447 -1.70211835 -7.32094029]
# epoch 335, negative log-likelihood 0.1198, w=[ 1.44916952 -1.68816829 -7.28273553]
# epoch 336, negative log-likelihood 0.1233, w=[ 1.16513534 -1.70126854 -7.33686399]
# epoch 337, negative log-likelihood 0.1193, w=[ 1.44902805 -1.68757091 -7.29932159]
# epoch 338, negative log-likelihood 0.1225, w=[ 1.16964801 -1.7004329  -7.35260588]
# epoch 339, negative log-likelihood 0.1187, w=[ 1.44885821 -1.68698721 -7.31572873]
# epoch 340, negative log-likelihood 0.1218, w=[ 1.1741431  -1.69961166 -7.3681685 ]
# epoch 341, negative log-likelihood 0.1181, w=[ 1.44866029 -1.68641743 -7.33195954]
# epoch 342, negative log-likelihood 0.1211, w=[ 1.17862125 -1.69880507 -7.38355439]
# epoch 343, negative log-likelihood 0.1176, w=[ 1.44843459 -1.68586186 -7.34801661]
# epoch 344, negative log-likelihood 0.1204, w=[ 1.18308311 -1.69801339 -7.39876607]
# epoch 345, negative log-likelihood 0.1171, w=[ 1.44818141 -1.6853208  -7.3639025 ]
# epoch 346, negative log-likelihood 0.1197, w=[ 1.18752928 -1.69723692 -7.41380604]
# epoch 347, negative log-likelihood 0.1165, w=[ 1.44790106 -1.68479457 -7.37961976]
# epoch 348, negative log-likelihood 0.1190, w=[ 1.19196038 -1.69647596 -7.42867679]
# epoch 349, negative log-likelihood 0.1160, w=[ 1.44759388 -1.68428352 -7.39517093]
# epoch 350, negative log-likelihood 0.1184, w=[ 1.19637701 -1.69573086 -7.44338081]
# epoch 351, negative log-likelihood 0.1155, w=[ 1.44726021 -1.68378801 -7.41055851]
# epoch 352, negative log-likelihood 0.1177, w=[ 1.20077976 -1.69500196 -7.45792056]
# epoch 353, negative log-likelihood 0.1150, w=[ 1.44690042 -1.68330843 -7.42578503]
# epoch 354, negative log-likelihood 0.1171, w=[ 1.20516919 -1.69428966 -7.47229851]
# epoch 355, negative log-likelihood 0.1145, w=[ 1.44651489 -1.68284521 -7.44085296]
# epoch 356, negative log-likelihood 0.1164, w=[ 1.20954586 -1.69359438 -7.48651712]
# epoch 357, negative log-likelihood 0.1140, w=[ 1.44610405 -1.68239877 -7.45576478]
# epoch 358, negative log-likelihood 0.1158, w=[ 1.2139103  -1.69291654 -7.50057885]
# epoch 359, negative log-likelihood 0.1135, w=[ 1.44566833 -1.68196961 -7.47052296]
# epoch 360, negative log-likelihood 0.1152, w=[ 1.21826302 -1.69225663 -7.51448613]
# epoch 361, negative log-likelihood 0.1131, w=[ 1.44520822 -1.6815582  -7.48512996]
# epoch 362, negative log-likelihood 0.1146, w=[ 1.22260449 -1.69161515 -7.52824144]
# epoch 363, negative log-likelihood 0.1126, w=[ 1.44472425 -1.68116507 -7.49958822]
# epoch 364, negative log-likelihood 0.1141, w=[ 1.22693515 -1.69099263 -7.5418472 ]
# epoch 365, negative log-likelihood 0.1121, w=[ 1.44421697 -1.68079079 -7.51390017]
# epoch 366, negative log-likelihood 0.1135, w=[ 1.23125542 -1.69038965 -7.5553059 ]
# epoch 367, negative log-likelihood 0.1117, w=[ 1.443687   -1.68043594 -7.52806824]
# epoch 368, negative log-likelihood 0.1130, w=[ 1.23556567 -1.6898068  -7.56861997]
# epoch 369, negative log-likelihood 0.1112, w=[ 1.44313501 -1.68010114 -7.54209484]
# epoch 370, negative log-likelihood 0.1124, w=[ 1.2398662  -1.68924474 -7.58179191]
# epoch 371, negative log-likelihood 0.1108, w=[ 1.44256173 -1.67978704 -7.55598238]
# epoch 372, negative log-likelihood 0.1119, w=[ 1.24415729 -1.68870414 -7.59482418]
# epoch 373, negative log-likelihood 0.1104, w=[ 1.44196796 -1.67949433 -7.56973326]
# epoch 374, negative log-likelihood 0.1114, w=[ 1.24843916 -1.6881857  -7.60771929]
# epoch 375, negative log-likelihood 0.1100, w=[ 1.44135457 -1.67922371 -7.58334987]
# epoch 376, negative log-likelihood 0.1109, w=[ 1.25271194 -1.6876902  -7.62047974]
# epoch 377, negative log-likelihood 0.1096, w=[ 1.44072252 -1.67897593 -7.59683459]
# epoch 378, negative log-likelihood 0.1104, w=[ 1.2569757  -1.68721841 -7.63310806]
# epoch 379, negative log-likelihood 0.1092, w=[ 1.44007284 -1.67875178 -7.61018981]
# epoch 380, negative log-likelihood 0.1099, w=[ 1.26123044 -1.68677118 -7.6456068 ]
# epoch 381, negative log-likelihood 0.1088, w=[ 1.43940668 -1.67855207 -7.62341789]
# epoch 382, negative log-likelihood 0.1094, w=[ 1.26547607 -1.68634938 -7.65797854]
# epoch 383, negative log-likelihood 0.1084, w=[ 1.43872526 -1.67837764 -7.6365212 ]
# epoch 384, negative log-likelihood 0.1090, w=[ 1.26971237 -1.6859539  -7.67022587]
# epoch 385, negative log-likelihood 0.1080, w=[ 1.43802996 -1.67822936 -7.64950209]
# epoch 386, negative log-likelihood 0.1086, w=[ 1.27393907 -1.6855857  -7.68235141]
# epoch 387, negative log-likelihood 0.1076, w=[ 1.43732223 -1.67810812 -7.66236292]
# epoch 388, negative log-likelihood 0.1081, w=[ 1.27815574 -1.68524576 -7.69435783]
# epoch 389, negative log-likelihood 0.1073, w=[ 1.43660368 -1.67801485 -7.67510601]
# epoch 390, negative log-likelihood 0.1077, w=[ 1.28236184 -1.68493509 -7.70624782]
# epoch 391, negative log-likelihood 0.1069, w=[ 1.43587604 -1.6779505  -7.68773371]
# epoch 392, negative log-likelihood 0.1073, w=[ 1.28655671 -1.68465474 -7.71802409]
# epoch 393, negative log-likelihood 0.1066, w=[ 1.43514118 -1.67791601 -7.70024833]
# epoch 394, negative log-likelihood 0.1069, w=[ 1.29073952 -1.68440577 -7.72968941]
# epoch 395, negative log-likelihood 0.1063, w=[ 1.43440112 -1.67791236 -7.71265219]
# epoch 396, negative log-likelihood 0.1066, w=[ 1.29490931 -1.68418928 -7.74124658]
# epoch 397, negative log-likelihood 0.1060, w=[ 1.43365803 -1.67794053 -7.72494759]
# epoch 398, negative log-likelihood 0.1062, w=[ 1.29906495 -1.68400638 -7.75269844]
# epoch 399, negative log-likelihood 0.1056, w=[ 1.43291425 -1.6780015  -7.73713681]
# epoch 400, negative log-likelihood 0.1059, w=[ 1.30320514 -1.68385818 -7.76404785]
# epoch 401, negative log-likelihood 0.1053, w=[ 1.43217226 -1.67809624 -7.74922212]
# epoch 402, negative log-likelihood 0.1055, w=[ 1.30732842 -1.68374581 -7.77529774]
# epoch 403, negative log-likelihood 0.1051, w=[ 1.43143471 -1.67822571 -7.76120579]
# epoch 404, negative log-likelihood 0.1052, w=[ 1.31143312 -1.68367039 -7.78645105]
# epoch 405, negative log-likelihood 0.1048, w=[ 1.43070442 -1.67839084 -7.77309004]
# epoch 406, negative log-likelihood 0.1049, w=[ 1.31551741 -1.68363302 -7.79751079]
# epoch 407, negative log-likelihood 0.1045, w=[ 1.42998434 -1.67859252 -7.7848771 ]
# epoch 408, negative log-likelihood 0.1046, w=[ 1.31957927 -1.68363477 -7.80847995]
# epoch 409, negative log-likelihood 0.1043, w=[ 1.42927761 -1.67883162 -7.79656917]
# epoch 410, negative log-likelihood 0.1043, w=[ 1.32361649 -1.6836767  -7.81936162]
# epoch 411, negative log-likelihood 0.1040, w=[ 1.42858748 -1.67910894 -7.80816841]
# epoch 412, negative log-likelihood 0.1041, w=[ 1.32762668 -1.68375979 -7.83015885]
# epoch 413, negative log-likelihood 0.1038, w=[ 1.42791734 -1.67942521 -7.81967697]
# epoch 414, negative log-likelihood 0.1038, w=[ 1.33160727 -1.68388499 -7.84087476]
# epoch 415, negative log-likelihood 0.1036, w=[ 1.4272707  -1.67978109 -7.83109698]
# epoch 416, negative log-likelihood 0.1036, w=[ 1.33555554 -1.68405314 -7.85151247]
# epoch 417, negative log-likelihood 0.1033, w=[ 1.42665118 -1.68017713 -7.84243052]
# epoch 418, negative log-likelihood 0.1034, w=[ 1.33946862 -1.68426503 -7.86207508]
# epoch 419, negative log-likelihood 0.1031, w=[ 1.42606245 -1.6806138  -7.85367965]
# epoch 420, negative log-likelihood 0.1031, w=[ 1.34334348 -1.68452133 -7.87256574]
# epoch 421, negative log-likelihood 0.1029, w=[ 1.42550824 -1.68109145 -7.86484638]
# epoch 422, negative log-likelihood 0.1029, w=[ 1.34717702 -1.68482258 -7.88298755]
# epoch 423, negative log-likelihood 0.1028, w=[ 1.42499231 -1.68161028 -7.87593272]
# epoch 424, negative log-likelihood 0.1027, w=[ 1.35096603 -1.68516923 -7.89334359]
# epoch 425, negative log-likelihood 0.1026, w=[ 1.42451839 -1.68217038 -7.88694061]
# epoch 426, negative log-likelihood 0.1026, w=[ 1.35470726 -1.68556155 -7.90363694]
# epoch 427, negative log-likelihood 0.1024, w=[ 1.42409017 -1.68277168 -7.89787197]
# epoch 428, negative log-likelihood 0.1024, w=[ 1.35839744 -1.68599967 -7.91387059]
# epoch 429, negative log-likelihood 0.1023, w=[ 1.42371125 -1.68341396 -7.90872868]
# epoch 430, negative log-likelihood 0.1022, w=[ 1.36203333 -1.68648358 -7.92404751]
# epoch 431, negative log-likelihood 0.1021, w=[ 1.42338512 -1.68409684 -7.91951257]
# epoch 432, negative log-likelihood 0.1021, w=[ 1.36561173 -1.68701307 -7.93417056]
# epoch 433, negative log-likelihood 0.1020, w=[ 1.42311507 -1.68481977 -7.93022545]
# epoch 434, negative log-likelihood 0.1020, w=[ 1.36912956 -1.68758776 -7.94424255]
# epoch 435, negative log-likelihood 0.1019, w=[ 1.42290422 -1.68558205 -7.94086908]
# epoch 436, negative log-likelihood 0.1018, w=[ 1.37258388 -1.6882071  -7.95426618]
# epoch 437, negative log-likelihood 0.1017, w=[ 1.4227554  -1.68638279 -7.95144518]
# epoch 438, negative log-likelihood 0.1017, w=[ 1.37597196 -1.68887035 -7.96424403]
# epoch 439, negative log-likelihood 0.1016, w=[ 1.42267119 -1.68722097 -7.96195544]
# epoch 440, negative log-likelihood 0.1016, w=[ 1.37929127 -1.68957662 -7.97417857]
# epoch 441, negative log-likelihood 0.1015, w=[ 1.42265382 -1.68809542 -7.97240152]
# epoch 442, negative log-likelihood 0.1015, w=[ 1.38253959 -1.6903248  -7.98407212]
# epoch 443, negative log-likelihood 0.1014, w=[ 1.42270518 -1.6890048  -7.98278504]
# epoch 444, negative log-likelihood 0.1014, w=[ 1.38571499 -1.69111366 -7.99392687]
# epoch 445, negative log-likelihood 0.1014, w=[ 1.42282676 -1.68994768 -7.99310758]
# epoch 446, negative log-likelihood 0.1013, w=[ 1.38881588 -1.6919418  -8.00374485]
# epoch 447, negative log-likelihood 0.1013, w=[ 1.42301967 -1.69092248 -8.00337069]
# epoch 448, negative log-likelihood 0.1012, w=[ 1.39184107 -1.69280768 -8.01352793]
# epoch 449, negative log-likelihood 0.1012, w=[ 1.42328459 -1.69192755 -8.0135759 ]
# epoch 450, negative log-likelihood 0.1012, w=[ 1.39478973 -1.69370963 -8.02327784]
# epoch 451, negative log-likelihood 0.1011, w=[ 1.42362176 -1.69296114 -8.02372469]
# epoch 452, negative log-likelihood 0.1011, w=[ 1.39766146 -1.6946459  -8.03299612]
# epoch 453, negative log-likelihood 0.1011, w=[ 1.42403102 -1.69402146 -8.03381853]
# epoch 454, negative log-likelihood 0.1010, w=[ 1.40045626 -1.69561464 -8.04268415]
# epoch 455, negative log-likelihood 0.1010, w=[ 1.42451175 -1.69510667 -8.04385885]
# epoch 456, negative log-likelihood 0.1010, w=[ 1.40317456 -1.69661393 -8.05234315]
# epoch 457, negative log-likelihood 0.1009, w=[ 1.42506295 -1.69621492 -8.05384706]
# epoch 458, negative log-likelihood 0.1009, w=[ 1.40581717 -1.69764181 -8.06197419]
# epoch 459, negative log-likelihood 0.1009, w=[ 1.42568322 -1.69734434 -8.06378453]
# epoch 460, negative log-likelihood 0.1008, w=[ 1.40838531 -1.69869629 -8.07157817]
# epoch 461, negative log-likelihood 0.1008, w=[ 1.42637079 -1.69849309 -8.0736726 ]
# epoch 462, negative log-likelihood 0.1008, w=[ 1.41088055 -1.6997754  -8.08115586]
# epoch 463, negative log-likelihood 0.1008, w=[ 1.42712356 -1.69965938 -8.0835126 ]
# epoch 464, negative log-likelihood 0.1007, w=[ 1.41330481 -1.70087716 -8.09070789]
# epoch 465, negative log-likelihood 0.1007, w=[ 1.42793914 -1.70084143 -8.09330579]
# epoch 466, negative log-likelihood 0.1007, w=[ 1.41566029 -1.70199963 -8.10023475]
# epoch 467, negative log-likelihood 0.1007, w=[ 1.42881487 -1.70203758 -8.10305344]
# epoch 468, negative log-likelihood 0.1006, w=[ 1.41794949 -1.70314092 -8.10973684]
# epoch 469, negative log-likelihood 0.1006, w=[ 1.42974787 -1.70324619 -8.11275676]
# epoch 470, negative log-likelihood 0.1006, w=[ 1.4201751  -1.70429919 -8.11921443]
# epoch 471, negative log-likelihood 0.1006, w=[ 1.43073508 -1.70446574 -8.12241693]
# epoch 472, negative log-likelihood 0.1006, w=[ 1.42234002 -1.70547271 -8.12866772]
# epoch 473, negative log-likelihood 0.1005, w=[ 1.43177332 -1.70569479 -8.13203508]
# epoch 474, negative log-likelihood 0.1005, w=[ 1.42444729 -1.70665978 -8.13809682]
# epoch 475, negative log-likelihood 0.1005, w=[ 1.43285932 -1.706932   -8.14161233]
# epoch 476, negative log-likelihood 0.1005, w=[ 1.42650002 -1.70785884 -8.14750177]
# epoch 477, negative log-likelihood 0.1005, w=[ 1.43398973 -1.70817612 -8.15114973]
# epoch 478, negative log-likelihood 0.1004, w=[ 1.42850142 -1.70906839 -8.15688256]
# epoch 479, negative log-likelihood 0.1004, w=[ 1.43516122 -1.709426   -8.1606483 ]
# epoch 480, negative log-likelihood 0.1004, w=[ 1.43045468 -1.71028705 -8.16623913]
# epoch 481, negative log-likelihood 0.1004, w=[ 1.43637047 -1.7106806  -8.17010902]
# epoch 482, negative log-likelihood 0.1004, w=[ 1.432363   -1.71151352 -8.17557138]
# epoch 483, negative log-likelihood 0.1003, w=[ 1.43761421 -1.71193896 -8.17953281]
# epoch 484, negative log-likelihood 0.1003, w=[ 1.43422953 -1.71274662 -8.1848792 ]
# epoch 485, negative log-likelihood 0.1003, w=[ 1.43888926 -1.71320022 -8.18892056]
# epoch 486, negative log-likelihood 0.1003, w=[ 1.43605732 -1.71398526 -8.19416245]
# epoch 487, negative log-likelihood 0.1003, w=[ 1.44019255 -1.71446361 -8.19827312]
# epoch 488, negative log-likelihood 0.1002, w=[ 1.43784936 -1.71522844 -8.20342099]
# epoch 489, negative log-likelihood 0.1002, w=[ 1.44152112 -1.71572844 -8.20759126]
# epoch 490, negative log-likelihood 0.1002, w=[ 1.43960847 -1.71647525 -8.21265465]
# epoch 491, negative log-likelihood 0.1002, w=[ 1.44287217 -1.71699409 -8.21687575]
# epoch 492, negative log-likelihood 0.1002, w=[ 1.44133737 -1.71772487 -8.22186328]
# epoch 493, negative log-likelihood 0.1002, w=[ 1.44424305 -1.71826002 -8.22612727]
# epoch 494, negative log-likelihood 0.1001, w=[ 1.44303861 -1.71897656 -8.23104675]
# epoch 495, negative log-likelihood 0.1001, w=[ 1.44563128 -1.71952575 -8.2353465 ]
# epoch 496, negative log-likelihood 0.1001, w=[ 1.4447146  -1.72022967 -8.24020491]
# epoch 497, negative log-likelihood 0.1001, w=[ 1.44703454 -1.72079085 -8.24453405]
# epoch 498, negative log-likelihood 0.1001, w=[ 1.44636757 -1.72148361 -8.24933765]
# epoch 499, negative log-likelihood 0.1001, w=[ 1.44845069 -1.72205497 -8.25369049]

# %% [markdown]
# # Plot error over iterations

# %%
plt.plot(range(max_iter), error_all)

# %%
# New Learning rate for gradient descent.
newlearning_rates = [0.5, 0.3, 0.1, 0.05, 0.01]
error_all_rates = []

# %%
for restarting in newlearning_rates:
  # We start over the initial parameters
    w = np.random.rand(3,)
    error_all = []  #Initialize error vector for each learning rate

    for iter2 in range(max_iter):
        Y_hat = sps.expit(np.dot(X, w))
        e2 = -1/max_iter * np.sum( np.multiply(np.log(Y_hat), Y) + np.multiply(np.log(1-Y_hat), (1-Y)))
        error_all.append(e2)

        grad_e = np.mean(np.multiply((Y_hat - Y), X.T), axis=1)

        w_old = w
        w = w - eta * grad_e

    error_all_rates.append(error_all)

# Plot error values for different learning rates
for i in range(len(newlearning_rates)):
    plt.plot(range(max_iter), error_all_rates[i])

# %%
#Scenario for the stochastic gradient descent
# New Learning rate for gradient descent.
newlearning_rates2 = [0.5, 0.3, 0.1, 0.05, 0.01]
error_all_rates2 = []

# %%
#for restarting2 in newlearning_rates2:
#    w = np.random.rand(3,)  # Re-initialize parameters for each learning rate
#    error_all = []  # Initialize error vector for each learning rate
#
#    for iter3 in range(max_iter):
#        # Randomly shuffle the training data (source https://appdividend.com/2022/02/19/np-random-permutation/ & https://www.geeksforgeeks.org/ml-stochastic-gradient-descent-sgd/)
#        indexes = np.random.permutation(len(X))
#        X_shuffled = X[indexes]
#        Y_shuffled = Y[indexes]

 #       for i in range(len(X_shuffled)):
 #         x = X_shuffled[i]
  #        y = Y_shuffled[i]
#          Y_hat = sps.expit(np.dot(X, w)) #ERROR we should used the x instead of X
   #       # Compute the error as before
    #      e3 = -1/max_iter * np.sum(np.multiply(np.log(Y_hat), y) + np.multiply(np.log(1-Y_hat), (1-y)))
     #     error_all.append(e3)
#          #grad_e = (Y_hat-y)*x
 #         grad_e = (Y_hat - np.full(Y_hat.shape, y)) * np.reshape(x, (200, 3))
  #        # Update the parameters w = w - restarting2 * grad_e
   # error_all_rates2.append(error_all)

# Plot error values for stochastic gradient descent
#for i in range(len(newlearning_rates2)):
#    plt.plot(range(max_iter), error_all_rates2[i])

# New Learning rate for stochastic gradient descent.
newlearning_rates3 = [0.5, 0.3, 0.1, 0.05, 0.01]
error_all_rates = []

for restarting3 in newlearning_rates3:
    w = np.random.rand(3,)  # Re-initialize parameters for each learning rate
    error_all = []  # Initialize error vector for each learning rate

    for iter3 in range(max_iter):
        # Randomly shuffle the training data
        indexes = np.random.permutation(len(X))
        X_shuffled = X[indexes]
        Y_shuffled = Y[indexes]

        for i in range(len(X_shuffled)):
            x = X_shuffled[i]
            y = Y_shuffled[i]
            Y_hat = sps.expit(np.dot(x, w))  # Update to use current example x
            e3 = -1 * (np.log(Y_hat) * y + np.log(1 - Y_hat) * (1 - y))  # Update error calculation for current example
            error_all.append(e3)

            grad_e = (Y_hat - y) * x  # Update gradient calculation for current example
            w = w - eta * grad_e

    error_all_rates.append(error_all)

# Plot error values for different learning rates
for i in range(len(newlearning_rates2)):
    plt.plot(range(max_iter * len(X)), error_all_rates[i])  # Update x-axis range based on number of examples
# Out:
# <ipython-input-17-d56e837d46ab>:44: RuntimeWarning: divide by zero encountered in log
#   e2 = -1 * (np.log(Y_hat) * y + np.log(1 - Y_hat) * (1 - y))  # Update error calculation for current example
# <ipython-input-17-d56e837d46ab>:44: RuntimeWarning: invalid value encountered in double_scalars
#   e2 = -1 * (np.log(Y_hat) * y + np.log(1 - Y_hat) * (1 - y))  # Update error calculation for current example
